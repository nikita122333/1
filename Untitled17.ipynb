# %% [markdown]
# <a href="https://colab.research.google.com/github/nikita122333/1/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
storage = {}

hash_func = len
def put(key: str, value: int) -> None: # o(1)

    hash_ = hash_func('string')
    ...

def get(key: str) -> int: # o(n), где n - глубина коллизии ключа key. Иными словами, максимальное количество элементов с одинаковым хэшом
    return ...

# %%
from typing import Any


class Queue:
    def __init__(self, size: int) -> None:
      queue = list()
      queue = [None]*size

    def append_right(self, x) -> bool:
      for i in range(size-1):
        if queue[i] != None and queue[i+1] == None:
          queue[i+1] = x
          break
        else:
          queue[0] = x
      if queue[i+1] ==x:
        print(True)
      else:
        print(False)
    def append_left(self, x) -> bool: # o(1)
      for i in range(1, size):
        if queue[i] != None and queue[i-1] == None:
          queue[i-1] = x
          break
        else:
          queue[0] = x
      if queue[i-1] ==x:
        print(True)
      else:
        print(False)
    def delete_right(self) -> bool: # o(1)
      for i in range(size-1):
        if queue[i] != None and queue[i+1] == None:
          queue[i] = None
          break
      if queue[i] ==None:
        print(True)
      else:
        print(False)
    def delete_left(self) -> bool: # o(1)
      for i in range(1, size):
        if queue[i] != None and queue[i-1] == None:
          queue[i] = None
          break
      if queue[i] ==None:
        print(True)
      else:
        print(False)
    def get_right(self) -> int: # o(1)
      for i in range(size-1):
        if queue[i] != None and queue[i+1] == None or i == size-1 and queue[i != None]:
          print(queue[i])
          break
        else:
          print(-1)

    def get_left(self) -> int: # o(1)
      for i in range(1, size):
        if queue[i] != None and queue[i-1] == None or i == 0 and queue[i != None]:
          print(queue[i])
          break
        else:
          print(-1)

    def is_empty(self) -> bool:
      for i in range(size):
        i

    def is_full(self) -> bool: # o(1)
        ...

# %%
def task2(a,b):
    if a>b:
        c = a
        while c%b != 0:
            c +=a
    else:
        c = b
        while c%a != 0:
            c +=b
    return c
task2(100001,5)
# Out:
# 500005

# %%
def task2(com1,com2):
    if com1>com2:
        c = com1
        while c%com2 != 0:
            c +=com1
    else:
        c = com2
        while c%com1 != 0:
            c +=com2
    return c
task2(7,5)
# Out:
# 35

# %%
a = ('esfgfdhf')
a.appen(23)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-32e9d25e5126> in <cell line: 0>()
#       1 a = ('esfgfdhf')
# ----> 2 a.append(23)
#       3 a
#
# AttributeError: 'str' object has no attribute 'append'

# %%
i = 'a'

# %%
q = "213rewfrgrh3tr"

# %%
q = q+ i

# %%
q
# Out:
# '213rewfrgrh3tra'

# %%
zipdnk = str()

# %%
zipdnk = zipdnk + i +'4'

# %%
zipdnk
# Out:
# 'a4'

# %%
for
if a == i:
  print('efd')

# %%
def task3(dnk):
  zipdnk = str()
  symb = "0"
  flag = 1
  for i in dnk:
    if i == symb:
      flag +=1
    elif symb == '0':
      pass
    else:
      zipdnk = zipdnk + symb + str(flag)
      flag = 1
    symb = i
  zipdnk = zipdnk + symb + str(flag)
  return(zipdnk)

# %%
a = 'aaaabbrrttttr'

# %%
a = list(a)

# %%
a
# Out:
# ['a', 'a', 'a', 'a', 'b', 'b', 'r', 'r', 't', 't', 't', 't', 'r']

# %%
def task4(string, substring):a
    count =0
    for i in substring:
      count +=1
    count2 = 0
    for i in string:
      count2 +=1

    for i in string:
      if flag == count:

      for sub in substring:
        if i == sub:
            flag +=1
        else:
          break
    return flag

# %%
task4('abaabf', 'aba')
# Out:
# b b
# a a
# b a
# a b
# b b
# a f
# 1

# %%
def task4(string, substring):
  string = list(string)
  substring = list(substring)
  flag = False
  sum = 0
  for ind in range(len(string)):
    if string[ind] == substring[0]:
      flag = True
      next_ind = ind+1
      e = 1
      while e<len(substring) and next_ind < len(string):
        if substring[e] != string[next_ind]:
          flag = False
        next_ind+=1
        e+=1
      if flag==True:
        sum+=1
  return(sum)

# %%
def task2(com1,com2):
    c = 0
    while c%com1 != 0 or c%com2!=0 or c ==0:
        if com1 > com2:
            c +=com1
        else:
            c +=com2
    return c

# %%
task2(3,5)
# Out:
# 15
